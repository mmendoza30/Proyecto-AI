# %% [markdown]
# # Regresión con ANN (predicción de una variable continua)
#
# #### Dataset: Student Performance (Versión CSV)
# #### Fuente: UC Irvine Machine Learning Repository
# #### Descripción: Desarrollo de un sistema que prediga el desempeño académico de estudiantes y detecte tempranamente riesgo de deserción. Alertas tempranas para implementar intervenciones educativas oportunas.
#
# Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
# 1. school - student's school (binary: "GP" - Gabriel Pereira or "MS" - Mousinho da Silveira)
#
# 2. sex - student's sex (binary: "F" - female or "M" - male)
#
# 3. age - student's age (numeric: from 15 to 22)
#
# 4. address - student's home address type (binary: "U" - urban or "R" - rural)
#
# 5. famsize - family size (binary: "LE3" - less or equal to 3 or "GT3" - greater than 3)
#
# 6. Pstatus - parent's cohabitation status (binary: "T" - living together or "A" - apart)
#
# 7. Medu - mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 8. Fedu - father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 9. Mjob - mother's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#
# 10. Fjob - father's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#
# 11. reason - reason to choose this school (nominal: close to "home", school "reputation", "course" preference or "other")
#
# 12. guardian - student's guardian (nominal: "mother", "father" or "other")
#
# 13. traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#
# 14. studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
# 15. failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# 16. schoolsup - extra educational support (binary: yes or no)
#
# 17. famsup - family educational support (binary: yes or no)
#
# 18. paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# 19. activities - extra-curricular activities (binary: yes or no)
#
# 20. nursery - attended nursery school (binary: yes or no)
#
# 21. higher - wants to take higher education (binary: yes or no)
#
# 22. internet - Internet access at home (binary: yes or no)
#
# 23. romantic - with a romantic relationship (binary: yes or no)
#
# 24. famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# 25. freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#
# 26. goout - going out with friends (numeric: from 1 - very low to 5 - very high)
#
# 27. Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 28. Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 29. health - current health status (numeric: from 1 - very bad to 5 - very good)
#
# 30. absences - number of school absences (numeric: from 0 to 93)
#
# these grades are related with the course subject, Math or Portuguese:
#
# 31. G1 - first period grade (numeric: from 0 to 20)
#
# 31. G2 - second period grade (numeric: from 0 to 20)
#
# 32. G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# ## Librerias

# %%
import sys
import os

# Pon la ruta exacta de la carpeta donde ESTÁ el archivo .py
ruta = r"D:\Proyecto1_IA\Proyecto-AI\src\train"

if ruta not in sys.path:
    sys.path.append(ruta)

# Intentar importar
from model1 import modelos
print("✅ Importado correctamente")
# Out:
# ✅ Importado correctamente

# %% [markdown]
# ## 6.Creación del modelo

# %%
import pandas as pd
from model1 import modelos

# %%
X_train = pd.read_csv('../data/processed/X_train.csv', sep=',', na_values=[''], quotechar='"')
X_test = pd.read_csv('../data/processed/X_test.csv', sep=',', na_values=[''], quotechar='"')
y_train = pd.read_csv('../data/processed/y_train.csv', sep=',', na_values=[''], quotechar='"')
y_test = pd.read_csv('../data/processed/y_test.csv', sep=',', na_values=[''], quotechar='"')

# %% [markdown]
# ## 6.Creación del modelo

# %%
modelo_regresion = modelos()

# %%
modelo_creado = modelo_regresion.create_model_regresion(X_train)

# %% [markdown]
# ## 7.Entrenamiento del modelo

# %%
historial =  modelo_regresion.entrenamiento_model_regresion(modelo_creado, X_train, y_train, X_test, y_test)
# Out:
# Epoch 1/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 114.3735 - val_loss: 92.7759
# Epoch 2/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 96.4465 - val_loss: 75.5347
# Epoch 3/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 78.5989 - val_loss: 56.9451
# Epoch 4/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 59.2930 - val_loss: 39.7434
# Epoch 5/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.1467 - val_loss: 26.6715
# Epoch 6/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.3657 - val_loss: 19.2716
# Epoch 7/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.8685 - val_loss: 16.2738
# Epoch 8/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.9389 - val_loss: 15.0487
# Epoch 9/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.3213 - val_loss: 14.3508
# Epoch 10/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.0731 - val_loss: 13.7387
# Epoch 11/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.5856 - val_loss: 13.1833
# Epoch 12/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.7481 - val_loss: 12.6712
# Epoch 13/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.4666 - val_loss: 12.3543
# Epoch 14/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.1535 - val_loss: 12.1083
# Epoch 15/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.3395 - val_loss: 11.7327
# Epoch 16/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.3951 - val_loss: 11.4054
# Epoch 17/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.9869 - val_loss: 10.9672
# Epoch 18/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.4372 - val_loss: 10.6134
# Epoch 19/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.2321 - val_loss: 10.3691
# Epoch 20/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.1014 - val_loss: 10.2595
# Epoch 21/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.2078 - val_loss: 9.8043
# Epoch 22/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.2277 - val_loss: 9.7367
# Epoch 23/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.1088 - val_loss: 9.4674
# Epoch 24/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.7810 - val_loss: 9.3516
# Epoch 25/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.0510 - val_loss: 9.1364
# Epoch 26/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.3069 - val_loss: 8.9366
# Epoch 27/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.7985 - val_loss: 8.9049
# Epoch 28/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.5872 - val_loss: 8.6761
# Epoch 29/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.7432 - val_loss: 8.4341
# Epoch 30/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.8763 - val_loss: 8.3586
# Epoch 31/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.3184 - val_loss: 8.3882
# Epoch 32/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.9923 - val_loss: 8.3517
# Epoch 33/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.2444 - val_loss: 8.3090
# Epoch 34/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.1871 - val_loss: 8.0749
# Epoch 35/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.0480 - val_loss: 8.0218
# Epoch 36/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.0611 - val_loss: 8.0179
# Epoch 37/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.9396 - val_loss: 7.6814
# Epoch 38/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.3458 - val_loss: 7.6392
# Epoch 39/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.7003 - val_loss: 7.5584
# Epoch 40/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.8235 - val_loss: 8.0273
# Epoch 41/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.4450 - val_loss: 7.3882
# Epoch 42/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.9942 - val_loss: 7.4392
# Epoch 43/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.9563 - val_loss: 7.3716
# Epoch 44/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.4393 - val_loss: 7.3434
# Epoch 45/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.4671 - val_loss: 7.3754
# Epoch 46/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.2193 - val_loss: 7.1011
# Epoch 47/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.1092 - val_loss: 7.2249
# Epoch 48/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.7327 - val_loss: 6.9965
# Epoch 49/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.3639 - val_loss: 6.7920
# Epoch 50/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.3869 - val_loss: 6.8498
# Epoch 51/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.7870 - val_loss: 6.6381
# Epoch 52/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.7293 - val_loss: 6.5719
# Epoch 53/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.0864 - val_loss: 6.6862
# Epoch 54/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.0073 - val_loss: 6.4595
# Epoch 55/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.3019 - val_loss: 6.4326
# Epoch 56/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.9685 - val_loss: 6.5803
# Epoch 57/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.9240 - val_loss: 6.4022
# Epoch 58/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.3851 - val_loss: 6.3967
# Epoch 59/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.8693 - val_loss: 6.2010
# Epoch 60/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.5629 - val_loss: 6.2262
# Epoch 61/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.0263 - val_loss: 6.2236
# Epoch 62/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.2074 - val_loss: 6.1309
# Epoch 63/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.4848 - val_loss: 6.0164
# Epoch 64/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.1340 - val_loss: 5.9959
# Epoch 65/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.8811 - val_loss: 6.0297
# Epoch 66/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.3993 - val_loss: 6.0759
# Epoch 67/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.6020 - val_loss: 5.9783
# Epoch 68/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.7316 - val_loss: 5.8475
# Epoch 69/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.4320 - val_loss: 5.8685
# Epoch 70/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.8921 - val_loss: 5.6632
# Epoch 71/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.2393 - val_loss: 5.6980
# Epoch 72/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.5318 - val_loss: 5.8906
# Epoch 73/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.7769 - val_loss: 5.5506
# Epoch 74/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.9299 - val_loss: 5.5131
# Epoch 75/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.9401 - val_loss: 5.3573
# Epoch 76/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.2538 - val_loss: 5.5132
# Epoch 77/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.8168 - val_loss: 5.4739
# Epoch 78/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.8330 - val_loss: 5.5605
# Epoch 79/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.2212 - val_loss: 5.3391
# Epoch 80/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.1786 - val_loss: 5.3080
# Epoch 81/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.2683 - val_loss: 5.5573
# Epoch 82/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.7230 - val_loss: 5.2983
# Epoch 83/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.3473 - val_loss: 5.4270
# Epoch 84/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.2767 - val_loss: 5.1979
# Epoch 85/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.6394 - val_loss: 5.1489
# Epoch 86/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.9501 - val_loss: 5.2007
# Epoch 87/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.6622 - val_loss: 4.9466
# Epoch 88/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.4279 - val_loss: 5.0379
# Epoch 89/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.1742 - val_loss: 5.0521
# Epoch 90/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.3076 - val_loss: 4.8178
# Epoch 91/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.7993 - val_loss: 4.9517
# Epoch 92/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.3566 - val_loss: 4.8198
# Epoch 93/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.2629 - val_loss: 4.8958
# Epoch 94/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.7574 - val_loss: 4.8528
# Epoch 95/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.6123 - val_loss: 4.6906
# Epoch 96/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.9328 - val_loss: 4.7475
# Epoch 97/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.5074 - val_loss: 4.5820
# Epoch 98/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.0824 - val_loss: 4.6832
# Epoch 99/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.6893 - val_loss: 4.7187
# Epoch 100/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.4612 - val_loss: 4.4255
# Epoch 101/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.2446 - val_loss: 4.5808
# Epoch 102/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.6440 - val_loss: 4.7410
# Epoch 103/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.4003 - val_loss: 4.3063
# Epoch 104/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.7359 - val_loss: 4.7834
# Epoch 105/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.9349 - val_loss: 4.2959
# Epoch 106/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.4980 - val_loss: 4.6240
# Epoch 107/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.7567 - val_loss: 4.5820
# Epoch 108/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.3236 - val_loss: 4.3909
# Epoch 109/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.6804 - val_loss: 4.3305
# Epoch 110/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.0125 - val_loss: 4.4956
# Epoch 111/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.9005 - val_loss: 4.3117
# Epoch 112/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.3518 - val_loss: 4.3508
# Epoch 113/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.0551 - val_loss: 4.4247
# Epoch 114/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.4459 - val_loss: 4.3681
# Epoch 115/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.4207 - val_loss: 4.2739
# Epoch 116/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9873 - val_loss: 4.3787
# Epoch 117/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.7944 - val_loss: 4.2213
# Epoch 118/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.3777 - val_loss: 4.1515
# Epoch 119/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6613 - val_loss: 4.2947
# Epoch 120/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.2785 - val_loss: 4.2516
# Epoch 121/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3809 - val_loss: 4.3312
# Epoch 122/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.8025 - val_loss: 4.2242
# Epoch 123/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.2160 - val_loss: 4.1482
# Epoch 124/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.2852 - val_loss: 4.1858
# Epoch 125/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7907 - val_loss: 4.1051
# Epoch 126/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.0954 - val_loss: 3.9903
# Epoch 127/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4430 - val_loss: 4.2077
# Epoch 128/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.2726 - val_loss: 4.3274
# Epoch 129/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8134 - val_loss: 4.0206
# Epoch 130/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.2161 - val_loss: 4.0217
# Epoch 131/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7607 - val_loss: 3.9677
# Epoch 132/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.9015 - val_loss: 4.1147
# Epoch 133/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4698 - val_loss: 3.9257
# Epoch 134/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.2339 - val_loss: 4.0241
# Epoch 135/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2381 - val_loss: 3.9212
# Epoch 136/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5437 - val_loss: 4.1942
# Epoch 137/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7247 - val_loss: 4.0943
# Epoch 138/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.1483 - val_loss: 4.0614
# Epoch 139/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.5505 - val_loss: 3.9158
# Epoch 140/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.2063 - val_loss: 4.1369
# Epoch 141/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9992 - val_loss: 3.9005
# Epoch 142/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5964 - val_loss: 4.0058
# Epoch 143/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5728 - val_loss: 4.0316
# Epoch 144/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.1334 - val_loss: 4.1725
# Epoch 145/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6977 - val_loss: 3.8017
# Epoch 146/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2692 - val_loss: 3.7867
# Epoch 147/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8869 - val_loss: 3.9110
# Epoch 148/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5697 - val_loss: 3.9545
# Epoch 149/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8147 - val_loss: 4.0163
# Epoch 150/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5039 - val_loss: 3.8098
# Epoch 151/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.7492 - val_loss: 3.9727
# Epoch 152/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5932 - val_loss: 3.9261
# Epoch 153/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5419 - val_loss: 4.0201
# Epoch 154/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6285 - val_loss: 4.0354
# Epoch 155/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1782 - val_loss: 4.2199
# Epoch 156/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.5646 - val_loss: 3.7643
# Epoch 157/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8660 - val_loss: 3.8622
# Epoch 158/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8300 - val_loss: 4.0790
# Epoch 159/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0965 - val_loss: 4.0167
# Epoch 160/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3883 - val_loss: 3.8956
# Epoch 161/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3156 - val_loss: 3.8240
# Epoch 162/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6839 - val_loss: 3.8315
# Epoch 163/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0191 - val_loss: 4.0467
# Epoch 164/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8646 - val_loss: 3.9549
# Epoch 165/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.9128 - val_loss: 4.0015
# Epoch 166/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3040 - val_loss: 3.9642
# Epoch 166: early stopping

# %% [markdown]
# ## 8. Evaluación del modelo

# %%
predictions, mae = modelo_regresion.evaluacion_modelo(historial, modelo_creado, X_test, y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# ------------------------------
# Mean Absolute Error (MAE): 1.3212
# Media de G3: 10.7512
# Error Relativo (MAE/Media): 12.29%
# ------------------------------

# %% [markdown]
# ## 8.1 Predicción sobre nuevos datos

# %%
modelo_creado.save(r"D:\Proyecto1_IA\Proyecto-AI\models\model1.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
