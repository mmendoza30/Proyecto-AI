# %% [markdown]
# # Regresión con ANN (predicción de una variable continua)
#
# #### Dataset: Student Performance (Versión CSV)
# #### Fuente: UC Irvine Machine Learning Repository
# #### Descripción: Desarrollo de un sistema que prediga el desempeño académico de estudiantes y detecte tempranamente riesgo de deserción. Alertas tempranas para implementar intervenciones educativas oportunas.
#
# Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
# 1. school - student's school (binary: "GP" - Gabriel Pereira or "MS" - Mousinho da Silveira)
#
# 2. sex - student's sex (binary: "F" - female or "M" - male)
#
# 3. age - student's age (numeric: from 15 to 22)
#
# 4. address - student's home address type (binary: "U" - urban or "R" - rural)
#
# 5. famsize - family size (binary: "LE3" - less or equal to 3 or "GT3" - greater than 3)
#
# 6. Pstatus - parent's cohabitation status (binary: "T" - living together or "A" - apart)
#
# 7. Medu - mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 8. Fedu - father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 9. Mjob - mother's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#
# 10. Fjob - father's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#
# 11. reason - reason to choose this school (nominal: close to "home", school "reputation", "course" preference or "other")
#
# 12. guardian - student's guardian (nominal: "mother", "father" or "other")
#
# 13. traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#
# 14. studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
# 15. failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# 16. schoolsup - extra educational support (binary: yes or no)
#
# 17. famsup - family educational support (binary: yes or no)
#
# 18. paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# 19. activities - extra-curricular activities (binary: yes or no)
#
# 20. nursery - attended nursery school (binary: yes or no)
#
# 21. higher - wants to take higher education (binary: yes or no)
#
# 22. internet - Internet access at home (binary: yes or no)
#
# 23. romantic - with a romantic relationship (binary: yes or no)
#
# 24. famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# 25. freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#
# 26. goout - going out with friends (numeric: from 1 - very low to 5 - very high)
#
# 27. Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 28. Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 29. health - current health status (numeric: from 1 - very bad to 5 - very good)
#
# 30. absences - number of school absences (numeric: from 0 to 93)
#
# these grades are related with the course subject, Math or Portuguese:
#
# 31. G1 - first period grade (numeric: from 0 to 20)
#
# 31. G2 - second period grade (numeric: from 0 to 20)
#
# 32. G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# ## Librerias

# %%
import sys
import os

# Pon la ruta exacta de la carpeta donde ESTÁ el archivo .py
#ruta = r"D:\Proyecto1_IA\Proyecto-AI\src\train"
ruta = r"C:\Users\monic\Documents\CUC\Inteligencia Artificial\Proyecto-AI\src\train"

if ruta not in sys.path:
    sys.path.append(ruta)

# Intentar importar
from model1 import modelos
print("✅ Importado correctamente")
# Out:
# ✅ Importado correctamente

# %% [markdown]
# ## 6.Creación del modelo

# %%
import pandas as pd
from model1 import modelos

# %%
X_train = pd.read_csv('../data/processed/X_train.csv', sep=',', na_values=[''], quotechar='"')
X_test = pd.read_csv('../data/processed/X_test.csv', sep=',', na_values=[''], quotechar='"')
y_train = pd.read_csv('../data/processed/y_train.csv', sep=',', na_values=[''], quotechar='"')
y_test = pd.read_csv('../data/processed/y_test.csv', sep=',', na_values=[''], quotechar='"')

X_train_scaled = pd.read_csv('../data/processed/X_train_scaled.csv')
X_test_scaled = pd.read_csv('../data/processed/X_test_scaled.csv')

# %% [markdown]
# ## 6.Creación del modelo

# %%
modelo_regresion = modelos()

# %%
#modelo_creado = modelo_regresion.create_model_regresion(X_train)
modelo_creado = modelo_regresion.create_model_regresion(X_train_scaled)

# %% [markdown]
# ## 7.Entrenamiento del modelo

# %%
#historial =  modelo_regresion.entrenamiento_model_regresion(modelo_creado, X_train, y_train, X_test, y_test)

historial =  modelo_regresion.entrenamiento_model_regresion(modelo_creado, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Epoch 1/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 127.5190 - val_loss: 81.9000
# Epoch 2/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 56.8701 - val_loss: 16.8883
# Epoch 3/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.9523 - val_loss: 15.7232
# Epoch 4/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.7315 - val_loss: 13.7949
# Epoch 5/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.3492 - val_loss: 13.0590
# Epoch 6/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.7075 - val_loss: 12.0366
# Epoch 7/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.0651 - val_loss: 11.2085
# Epoch 8/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.7947 - val_loss: 10.4211
# Epoch 9/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.9183 - val_loss: 9.4001
# Epoch 10/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.6413 - val_loss: 8.5118
# Epoch 11/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.5329 - val_loss: 7.6677
# Epoch 12/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6940 - val_loss: 7.1180
# Epoch 13/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2512 - val_loss: 6.5982
# Epoch 14/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3696 - val_loss: 6.1619
# Epoch 15/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9340 - val_loss: 6.0167
# Epoch 16/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1911 - val_loss: 5.5892
# Epoch 17/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2574 - val_loss: 5.3448
# Epoch 18/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1803 - val_loss: 5.1340
# Epoch 19/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4111 - val_loss: 4.7644
# Epoch 20/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0563 - val_loss: 4.6325
# Epoch 21/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0554 - val_loss: 4.4162
# Epoch 22/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3155 - val_loss: 4.3635
# Epoch 23/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6008 - val_loss: 4.2509
# Epoch 24/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4860 - val_loss: 4.1421
# Epoch 25/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1006 - val_loss: 4.0132
# Epoch 26/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0083 - val_loss: 4.2872
# Epoch 27/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8482 - val_loss: 3.9968
# Epoch 28/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8451 - val_loss: 3.8423
# Epoch 29/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9866 - val_loss: 3.7396
# Epoch 30/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5971 - val_loss: 3.7334
# Epoch 31/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8215 - val_loss: 3.7179
# Epoch 32/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0912 - val_loss: 3.7605
# Epoch 33/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4773 - val_loss: 3.5609
# Epoch 34/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1944 - val_loss: 3.4932
# Epoch 35/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7087 - val_loss: 3.4779
# Epoch 36/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5127 - val_loss: 3.5377
# Epoch 37/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1998 - val_loss: 3.4969
# Epoch 38/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5269 - val_loss: 3.2776
# Epoch 39/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4264 - val_loss: 3.2817
# Epoch 40/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2639 - val_loss: 3.2453
# Epoch 41/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1022 - val_loss: 3.3162
# Epoch 42/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2822 - val_loss: 3.2360
# Epoch 43/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7537 - val_loss: 3.1916
# Epoch 44/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9808 - val_loss: 3.1779
# Epoch 45/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4470 - val_loss: 3.1028
# Epoch 46/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7989 - val_loss: 3.2436
# Epoch 47/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2888 - val_loss: 3.1084
# Epoch 48/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1576 - val_loss: 3.0455
# Epoch 49/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9735 - val_loss: 3.2294
# Epoch 50/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9875 - val_loss: 3.0705
# Epoch 51/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0730 - val_loss: 2.9559
# Epoch 52/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4094 - val_loss: 3.2394
# Epoch 53/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5831 - val_loss: 2.9875
# Epoch 54/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0161 - val_loss: 3.0770
# Epoch 55/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9199 - val_loss: 2.9543
# Epoch 56/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7842 - val_loss: 3.0418
# Epoch 57/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6215 - val_loss: 2.8594
# Epoch 58/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1344 - val_loss: 2.8344
# Epoch 59/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0230 - val_loss: 2.8820
# Epoch 60/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1278 - val_loss: 2.9612
# Epoch 61/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4336 - val_loss: 2.8566
# Epoch 62/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3493 - val_loss: 2.7587
# Epoch 63/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5105 - val_loss: 2.6939
# Epoch 64/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7894 - val_loss: 2.7837
# Epoch 65/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7204 - val_loss: 2.8119
# Epoch 66/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5040 - val_loss: 2.7438
# Epoch 67/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2837 - val_loss: 2.6763
# Epoch 68/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5143 - val_loss: 2.7801
# Epoch 69/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1371 - val_loss: 2.7188
# Epoch 70/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4061 - val_loss: 2.6815
# Epoch 71/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2672 - val_loss: 2.7630
# Epoch 72/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2293 - val_loss: 2.6951
# Epoch 73/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3752 - val_loss: 2.6641
# Epoch 74/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2797 - val_loss: 2.6964
# Epoch 75/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1942 - val_loss: 2.7400
# Epoch 76/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2685 - val_loss: 2.6437
# Epoch 77/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0275 - val_loss: 2.6481
# Epoch 78/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1632 - val_loss: 2.6681
# Epoch 79/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2371 - val_loss: 2.7747
# Epoch 80/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9015 - val_loss: 2.7087
# Epoch 81/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4432 - val_loss: 2.6414
# Epoch 82/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1725 - val_loss: 2.8595
# Epoch 83/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9296 - val_loss: 2.5500
# Epoch 84/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2812 - val_loss: 2.6759
# Epoch 85/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3302 - val_loss: 2.7791
# Epoch 86/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0426 - val_loss: 2.6398
# Epoch 87/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0552 - val_loss: 2.5834
# Epoch 88/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1486 - val_loss: 2.6081
# Epoch 89/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1278 - val_loss: 2.6366
# Epoch 90/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0174 - val_loss: 2.6398
# Epoch 91/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9840 - val_loss: 2.8110
# Epoch 92/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9089 - val_loss: 2.6915
# Epoch 93/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9990 - val_loss: 2.7643
# Epoch 93: early stopping

# %% [markdown]
# ## 8. Evaluación del modelo

# %%
#predictions, mae = modelo_regresion.evaluacion_modelo(historial, modelo_creado, X_test, y_test)
predictions, mae = modelo_regresion.evaluacion_modelo(historial, modelo_creado, X_test_scaled, y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# ------------------------------
# Mean Absolute Error (MAE): 1.1183
# Media de G3: 10.7512
# Error Relativo (MAE/Media): 10.40%
# ------------------------------

# %% [markdown]
# ## 8.1 Predicción sobre nuevos datos

# %%
import pickle

with open('../models/columns.pkl', 'wb') as f:
    pickle.dump(X_train.columns.tolist(), f)

# %%
#modelo_creado.save(r"D:\Proyecto1_IA\Proyecto-AI\models\model1.h5")
modelo_creado.save(r"C:\Users\monic\Documents\CUC\Inteligencia Artificial\Proyecto-AI\models\model1.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
