# %% [markdown]
# # Regresión con ANN (predicción de una variable continua)
#
# #### Dataset: Student Performance (Versión CSV)
# #### Fuente: UC Irvine Machine Learning Repository
# #### Descripción: Desarrollo de un sistema que prediga el desempeño académico de estudiantes y detecte tempranamente riesgo de deserción. Alertas tempranas para implementar intervenciones educativas oportunas.
#
# Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
# 1. school - student's school (binary: "GP" - Gabriel Pereira or "MS" - Mousinho da Silveira)
#
# 2. sex - student's sex (binary: "F" - female or "M" - male)
#
# 3. age - student's age (numeric: from 15 to 22)
#
# 4. address - student's home address type (binary: "U" - urban or "R" - rural)
#
# 5. famsize - family size (binary: "LE3" - less or equal to 3 or "GT3" - greater than 3)
#
# 6. Pstatus - parent's cohabitation status (binary: "T" - living together or "A" - apart)
#
# 7. Medu - mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 8. Fedu - father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 9. Mjob - mother's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#
# 10. Fjob - father's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#
# 11. reason - reason to choose this school (nominal: close to "home", school "reputation", "course" preference or "other")
#
# 12. guardian - student's guardian (nominal: "mother", "father" or "other")
#
# 13. traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#
# 14. studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
# 15. failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# 16. schoolsup - extra educational support (binary: yes or no)
#
# 17. famsup - family educational support (binary: yes or no)
#
# 18. paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# 19. activities - extra-curricular activities (binary: yes or no)
#
# 20. nursery - attended nursery school (binary: yes or no)
#
# 21. higher - wants to take higher education (binary: yes or no)
#
# 22. internet - Internet access at home (binary: yes or no)
#
# 23. romantic - with a romantic relationship (binary: yes or no)
#
# 24. famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# 25. freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#
# 26. goout - going out with friends (numeric: from 1 - very low to 5 - very high)
#
# 27. Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 28. Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 29. health - current health status (numeric: from 1 - very bad to 5 - very good)
#
# 30. absences - number of school absences (numeric: from 0 to 93)
#
# these grades are related with the course subject, Math or Portuguese:
#
# 31. G1 - first period grade (numeric: from 0 to 20)
#
# 31. G2 - second period grade (numeric: from 0 to 20)
#
# 32. G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# ## Librerias

# %%
import pandas as pd
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.train.model1 import modelos
print("✅ Funciona")
# Out:
# ✅ Funciona

# %% [markdown]
# ## 6.Creación del modelo

# %%
import pandas as pd
from model1 import modelos

# %%
X_train = pd.read_csv('../data/processed/X_train.csv', sep=',', na_values=[''], quotechar='"')
X_test = pd.read_csv('../data/processed/X_test.csv', sep=',', na_values=[''], quotechar='"')
y_train = pd.read_csv('../data/processed/y_train.csv', sep=',', na_values=[''], quotechar='"')
y_test = pd.read_csv('../data/processed/y_test.csv', sep=',', na_values=[''], quotechar='"')

X_train_scaled = pd.read_csv('../data/processed/X_train_scaled.csv')
X_test_scaled = pd.read_csv('../data/processed/X_test_scaled.csv')

# %% [markdown]
# ## 6.Creación del modelo

# %%
modelo_regresion = modelos()

# %%
#modelo_creado = modelo_regresion.create_model_regresion(X_train)
modelo_creado = modelo_regresion.create_model_regresion(X_train_scaled)

# %% [markdown]
# ## 7.Entrenamiento del modelo

# %%
#historial =  modelo_regresion.entrenamiento_model_regresion(modelo_creado, X_train, y_train, X_test, y_test)

historial =  modelo_regresion.entrenamiento_model_regresion(modelo_creado, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Epoch 1/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 135.0986 - val_loss: 92.4191
# Epoch 2/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.1035 - val_loss: 16.7163
# Epoch 3/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.6043 - val_loss: 15.3259
# Epoch 4/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.2737 - val_loss: 14.0815
# Epoch 5/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.0672 - val_loss: 12.7187
# Epoch 6/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.8939 - val_loss: 11.5698
# Epoch 7/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.6865 - val_loss: 10.6401
# Epoch 8/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.2230 - val_loss: 9.8429
# Epoch 9/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.1560 - val_loss: 9.0691
# Epoch 10/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.1009 - val_loss: 8.4737
# Epoch 11/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4511 - val_loss: 7.9732
# Epoch 12/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2634 - val_loss: 7.5127
# Epoch 13/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9397 - val_loss: 7.0357
# Epoch 14/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3898 - val_loss: 6.7091
# Epoch 15/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.6267 - val_loss: 6.5521
# Epoch 16/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.9102 - val_loss: 6.1037
# Epoch 17/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7428 - val_loss: 6.1023
# Epoch 18/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8757 - val_loss: 5.6997
# Epoch 19/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1204 - val_loss: 5.2344
# Epoch 20/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6917 - val_loss: 5.1080
# Epoch 21/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4756 - val_loss: 4.9997
# Epoch 22/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0094 - val_loss: 4.8269
# Epoch 23/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5006 - val_loss: 4.7268
# Epoch 24/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4828 - val_loss: 4.4694
# Epoch 25/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1431 - val_loss: 4.3787
# Epoch 26/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0290 - val_loss: 4.3088
# Epoch 27/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1004 - val_loss: 4.1994
# Epoch 28/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0717 - val_loss: 4.1877
# Epoch 29/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0232 - val_loss: 4.1107
# Epoch 30/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5420 - val_loss: 3.8654
# Epoch 31/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6837 - val_loss: 3.8236
# Epoch 32/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3595 - val_loss: 3.7697
# Epoch 33/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5801 - val_loss: 3.7205
# Epoch 34/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5345 - val_loss: 3.6670
# Epoch 35/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9171 - val_loss: 3.5796
# Epoch 36/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2901 - val_loss: 3.6352
# Epoch 37/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4694 - val_loss: 3.6371
# Epoch 38/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4770 - val_loss: 3.6034
# Epoch 39/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3086 - val_loss: 3.4641
# Epoch 40/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0290 - val_loss: 3.4576
# Epoch 41/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2606 - val_loss: 3.4744
# Epoch 42/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1473 - val_loss: 3.4319
# Epoch 43/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4906 - val_loss: 3.5860
# Epoch 44/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1515 - val_loss: 3.4649
# Epoch 45/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3187 - val_loss: 3.7150
# Epoch 46/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9153 - val_loss: 3.3187
# Epoch 47/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2634 - val_loss: 3.2897
# Epoch 48/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8043 - val_loss: 3.2455
# Epoch 49/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0495 - val_loss: 3.3416
# Epoch 50/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7717 - val_loss: 3.2339
# Epoch 51/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.6637 - val_loss: 3.1939
# Epoch 52/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9507 - val_loss: 3.1455
# Epoch 53/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7530 - val_loss: 3.1518
# Epoch 54/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4026 - val_loss: 3.0701
# Epoch 55/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5681 - val_loss: 3.0729
# Epoch 56/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8149 - val_loss: 3.1130
# Epoch 57/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8120 - val_loss: 3.5458
# Epoch 58/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8207 - val_loss: 3.0142
# Epoch 59/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4446 - val_loss: 3.2616
# Epoch 60/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3894 - val_loss: 3.1025
# Epoch 61/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4757 - val_loss: 3.0384
# Epoch 62/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3256 - val_loss: 3.0391
# Epoch 63/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4438 - val_loss: 2.9606
# Epoch 64/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4016 - val_loss: 3.0330
# Epoch 65/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4522 - val_loss: 3.0701
# Epoch 66/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8998 - val_loss: 3.0340
# Epoch 67/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3366 - val_loss: 3.0944
# Epoch 68/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4645 - val_loss: 3.1814
# Epoch 69/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0394 - val_loss: 3.0282
# Epoch 70/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1264 - val_loss: 3.0548
# Epoch 71/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3743 - val_loss: 3.0087
# Epoch 72/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0631 - val_loss: 3.0158
# Epoch 73/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9101 - val_loss: 3.0130
# Epoch 73: early stopping

# %% [markdown]
# ## 8. Evaluación del modelo

# %%
predictions, mae = modelo_regresion.evaluacion_modelo(historial, modelo_creado, X_test_scaled, y_test)
# Out:
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000025F3F0ADE40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000025F3F0ADE40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# ------------------------------
# Mean Absolute Error (MAE): 1.1118
# Media de G3: 10.7512
# Error Relativo (MAE/Media): 10.34%
# ------------------------------

# %% [markdown]
# ## 8.1 Predicción sobre nuevos datos

# %%
import pickle

with open('../models/columns.pkl', 'wb') as f:
    pickle.dump(X_train.columns.tolist(), f)

# %%
#modelo_creado.save(r"D:\Proyecto1_IA\Proyecto-AI\models\model1.h5")
modelo_creado.save(r"C:\Users\monic\Documents\CUC\Inteligencia Artificial\Proyecto-AI\models\model1.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
