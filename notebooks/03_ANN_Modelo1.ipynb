# %% [markdown]
# # Regresión con ANN (predicción de una variable continua)
#
# #### Dataset: Student Performance (Versión CSV)
# #### Fuente: UC Irvine Machine Learning Repository
# #### Descripción: Desarrollo de un sistema que prediga el desempeño académico de estudiantes y detecte tempranamente riesgo de deserción. Alertas tempranas para implementar intervenciones educativas oportunas.
#
# Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
# 1. school - student's school (binary: "GP" - Gabriel Pereira or "MS" - Mousinho da Silveira)
#
# 2. sex - student's sex (binary: "F" - female or "M" - male)
#
# 3. age - student's age (numeric: from 15 to 22)
#
# 4. address - student's home address type (binary: "U" - urban or "R" - rural)
#
# 5. famsize - family size (binary: "LE3" - less or equal to 3 or "GT3" - greater than 3)
#
# 6. Pstatus - parent's cohabitation status (binary: "T" - living together or "A" - apart)
#
# 7. Medu - mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 8. Fedu - father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 9. Mjob - mother's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#
# 10. Fjob - father's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#
# 11. reason - reason to choose this school (nominal: close to "home", school "reputation", "course" preference or "other")
#
# 12. guardian - student's guardian (nominal: "mother", "father" or "other")
#
# 13. traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#
# 14. studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
# 15. failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# 16. schoolsup - extra educational support (binary: yes or no)
#
# 17. famsup - family educational support (binary: yes or no)
#
# 18. paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# 19. activities - extra-curricular activities (binary: yes or no)
#
# 20. nursery - attended nursery school (binary: yes or no)
#
# 21. higher - wants to take higher education (binary: yes or no)
#
# 22. internet - Internet access at home (binary: yes or no)
#
# 23. romantic - with a romantic relationship (binary: yes or no)
#
# 24. famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# 25. freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#
# 26. goout - going out with friends (numeric: from 1 - very low to 5 - very high)
#
# 27. Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 28. Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 29. health - current health status (numeric: from 1 - very bad to 5 - very good)
#
# 30. absences - number of school absences (numeric: from 0 to 93)
#
# these grades are related with the course subject, Math or Portuguese:
#
# 31. G1 - first period grade (numeric: from 0 to 20)
#
# 31. G2 - second period grade (numeric: from 0 to 20)
#
# 32. G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# ## Librerias

# %%
import pandas as pd
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.train.model1 import modelos
print("✅ Funciona")
# Out:
# ✅ Funciona

# %% [markdown]
# ## 6.Creación del modelo

# %%
X_train = pd.read_csv('../data/processed/X_train.csv', sep=',', na_values=[''], quotechar='"')
X_test = pd.read_csv('../data/processed/X_test.csv', sep=',', na_values=[''], quotechar='"')
y_train = pd.read_csv('../data/processed/y_train.csv', sep=',', na_values=[''], quotechar='"')
y_test = pd.read_csv('../data/processed/y_test.csv', sep=',', na_values=[''], quotechar='"')

X_train_scaled = pd.read_csv('../data/processed/X_train_scaled.csv')
X_test_scaled = pd.read_csv('../data/processed/X_test_scaled.csv')

# %% [markdown]
# ## 6.Creación del modelo

# %%
modelo_regresion = modelos()

# %%
#modelo_creado = modelo_regresion.create_model_regresion(X_train)
modelo_creado = modelo_regresion.create_model_regresion(X_train_scaled)

# %% [markdown]
# ## 7.Entrenamiento del modelo

# %%
#historial =  modelo_regresion.entrenamiento_model_regresion(modelo_creado, X_train, y_train, X_test, y_test)

historial =  modelo_regresion.entrenamiento_model_regresion(modelo_creado, X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# Epoch 1/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 118.9214 - val_loss: 71.0223
# Epoch 2/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 47.3175 - val_loss: 14.6582
# Epoch 3/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.5079 - val_loss: 13.9338
# Epoch 4/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.9965 - val_loss: 13.0349
# Epoch 5/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.9076 - val_loss: 12.1232
# Epoch 6/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.4484 - val_loss: 11.6496
# Epoch 7/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.7038 - val_loss: 10.4483
# Epoch 8/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.4502 - val_loss: 9.7624
# Epoch 9/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.0485 - val_loss: 8.8548
# Epoch 10/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.8177 - val_loss: 8.4007
# Epoch 11/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9281 - val_loss: 7.7098
# Epoch 12/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6169 - val_loss: 7.3320
# Epoch 13/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2851 - val_loss: 6.6723
# Epoch 14/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1911 - val_loss: 6.2371
# Epoch 15/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5026 - val_loss: 5.9647
# Epoch 16/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7029 - val_loss: 5.4940
# Epoch 17/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2056 - val_loss: 5.2941
# Epoch 18/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8079 - val_loss: 5.1134
# Epoch 19/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9439 - val_loss: 4.9164
# Epoch 20/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9752 - val_loss: 4.8281
# Epoch 21/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5323 - val_loss: 4.6707
# Epoch 22/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6760 - val_loss: 4.6430
# Epoch 23/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2162 - val_loss: 4.3161
# Epoch 24/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1836 - val_loss: 4.2226
# Epoch 25/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0221 - val_loss: 4.1418
# Epoch 26/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6953 - val_loss: 4.0937
# Epoch 27/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3065 - val_loss: 4.0276
# Epoch 28/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0111 - val_loss: 3.9642
# Epoch 29/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1600 - val_loss: 3.8702
# Epoch 30/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9197 - val_loss: 3.8276
# Epoch 31/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2078 - val_loss: 3.8317
# Epoch 32/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0609 - val_loss: 3.8367
# Epoch 33/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7647 - val_loss: 3.7756
# Epoch 34/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8897 - val_loss: 3.7638
# Epoch 35/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7859 - val_loss: 3.8429
# Epoch 36/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5948 - val_loss: 3.8345
# Epoch 37/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6898 - val_loss: 3.7616
# Epoch 38/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6845 - val_loss: 3.6616
# Epoch 39/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7738 - val_loss: 3.5914
# Epoch 40/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1995 - val_loss: 3.5385
# Epoch 41/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7195 - val_loss: 3.5316
# Epoch 42/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4146 - val_loss: 3.5730
# Epoch 43/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5985 - val_loss: 3.4902
# Epoch 44/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5766 - val_loss: 3.4391
# Epoch 45/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4534 - val_loss: 3.4562
# Epoch 46/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3130 - val_loss: 3.4602
# Epoch 47/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1459 - val_loss: 3.7315
# Epoch 48/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3880 - val_loss: 3.3961
# Epoch 49/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4640 - val_loss: 3.3840
# Epoch 50/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3022 - val_loss: 3.3586
# Epoch 51/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4040 - val_loss: 3.4036
# Epoch 52/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3780 - val_loss: 3.3646
# Epoch 53/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6321 - val_loss: 3.3220
# Epoch 54/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0103 - val_loss: 3.2788
# Epoch 55/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2666 - val_loss: 3.3376
# Epoch 56/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2912 - val_loss: 3.3498
# Epoch 57/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3400 - val_loss: 3.7655
# Epoch 58/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7818 - val_loss: 3.3850
# Epoch 59/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9413 - val_loss: 3.3331
# Epoch 60/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5667 - val_loss: 3.3091
# Epoch 61/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3076 - val_loss: 3.1892
# Epoch 62/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9990 - val_loss: 3.1299
# Epoch 63/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9063 - val_loss: 3.3382
# Epoch 64/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1032 - val_loss: 3.1280
# Epoch 65/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1237 - val_loss: 3.2015
# Epoch 66/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7389 - val_loss: 3.0818
# Epoch 67/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0778 - val_loss: 3.1439
# Epoch 68/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7714 - val_loss: 3.1322
# Epoch 69/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3962 - val_loss: 3.2403
# Epoch 70/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8038 - val_loss: 3.1203
# Epoch 71/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8360 - val_loss: 3.0908
# Epoch 72/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4043 - val_loss: 3.0948
# Epoch 73/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6748 - val_loss: 3.1050
# Epoch 74/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4679 - val_loss: 3.3942
# Epoch 75/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6281 - val_loss: 3.1237
# Epoch 76/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8625 - val_loss: 3.0597
# Epoch 77/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6445 - val_loss: 3.0122
# Epoch 78/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0773 - val_loss: 3.0070
# Epoch 79/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6067 - val_loss: 2.9923
# Epoch 80/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2186 - val_loss: 3.0511
# Epoch 81/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2597 - val_loss: 2.9738
# Epoch 82/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6601 - val_loss: 3.0983
# Epoch 83/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4360 - val_loss: 2.9765
# Epoch 84/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0242 - val_loss: 2.9325
# Epoch 85/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1387 - val_loss: 3.0856
# Epoch 86/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4597 - val_loss: 2.9617
# Epoch 87/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1614 - val_loss: 3.1144
# Epoch 88/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5796 - val_loss: 3.1804
# Epoch 89/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5254 - val_loss: 3.1163
# Epoch 90/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1946 - val_loss: 3.0988
# Epoch 91/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3349 - val_loss: 3.2582
# Epoch 92/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4035 - val_loss: 3.1052
# Epoch 93/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1980 - val_loss: 3.1894
# Epoch 94/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3227 - val_loss: 3.1417
# Epoch 94: early stopping

# %% [markdown]
# ## 8. Evaluación del modelo

# %%
predictions, mae = modelo_regresion.evaluacion_modelo(historial, modelo_creado, X_test_scaled, y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ------------------------------
# Mean Absolute Error (MAE): 1.2137
# Media de G3: 10.7512
# Error Relativo (MAE/Media): 11.29%
# ------------------------------

# %% [markdown]
# ## 8.1 Predicción sobre nuevos datos

# %%
import pickle

with open('../models/columns.pkl', 'wb') as f:
    pickle.dump(X_train.columns.tolist(), f)

# %%
#modelo_creado.save(r"D:\Proyecto1_IA\Proyecto-AI\models\model1.h5")
modelo_creado.save(r"C:\Users\monic\Documents\CUC\Inteligencia Artificial\Proyecto-AI\models\model1.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
